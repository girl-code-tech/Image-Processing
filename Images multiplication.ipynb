# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

# %%
img= cv.imread('D:\Downloads\Lenaaa.png', 0)
print(img)
#img=img*3
img1=cv.imread('D:\Downloads\FDP.jfif',1)
print(img1)
image00=cv.imread('D:\Downloads\dora.png')
print(image00)
print(img.shape)
print(img1.shape)
print(image00.shape)




plt.subplot(331)
plt.imshow(img)






plt.subplot(332)
plt.imshow(img1)

plt.subplot(333)
plt.imshow(image00)
plt.show()





newImage=np.matmul(image00, img1)
print(newImage)
# Out:
# [[168 168 167 ... 171 177 154]
#  [168 167 167 ... 174 182 158]
#  [169 166 167 ... 150 132  99]
#  ...
#  [ 59  61  64 ...  82  98 102]
#  [ 56  61  61 ...  95 110 111]
#  [ 53  61  59 ... 106 116 118]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
# ...
