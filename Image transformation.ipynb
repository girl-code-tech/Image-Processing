# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img = cv.imread('/home/students/Downloads/index.jpeg')

img = img[:,:,[2,1,0]]

# img1 = img[0:75,0:100,0]

#img2 = img[75:,100:,0]

img[0:74,:,1] = 4
img[75:,100:,0] = 4
img[50:55,:,1] = 225
img[50:55,:,1] = 225
img[50:55,:,1] = 225
img[76:,90:100,0] = 225
img[76:,90:100,1] = 225
img[76:,90:100,2] = 225
img[51:,0:80,2] = 225



plt.imshow(img)

plt.imsave("AmjadSAeed.jpg",img)

# plt.subplot(1,3,2)
# plt.imshow(img1)

# plt.subplot(1,3,3)
# plt.imshow(img2)

# %%
+-+
